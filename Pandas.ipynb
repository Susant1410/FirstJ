# %%
import pandas as pd

# %%
pd.read_csv('Book1.csv')
# Out:
#                  Name                      Email     Address     Pin Gender
# 0       Susanta Panda  kumarsusant.bbl@gmail.com     Kalinga  758034      M
# 1  Madhu Chanda Panda      Madhususant@gmail.com     Kalinga  758034      F
# 2      Kamalini Panda            Kp142@gmail.com  Matkambeda  758035      F
# 3  Gagan Bihari Panda              gbp@gmail.com  Matkambeda  758035      M

# %%
pd.read_csv('population-2010-2019.csv')
# Out:
#            1            2     3       4            5           6         7  \
# 0      LocID     Location  Time  AgeGrp  AgeGrpStart  AgeGrpSpan   PopMale
# 1          4  Afghanistan  2010     0-4            0           5   2715.07
# 2          8      Albania  2010     0-4            0           5    92.622
# 3         12      Algeria  2010     0-4            0           5  1966.415
# 4         24       Angola  2010     0-4            0           5  2233.041
# ...      ...          ...   ...     ...          ...         ...       ...
# 41791    430      Liberia  2019    100+          100          -1         0
# 41792    882        Samoa  2019    100+          100          -1         0
# 41793    768         Togo  2019    100+          100          -1         0
# 41794    776        Tonga  2019    100+          100          -1         0
# 41795    548      Vanuatu  2019    100+          100          -1         0
#
#                8         9
# 0      PopFemale  PopTotal
# ...

# %%
dffdfdsss

# %%
df = pd.read_csv('population-2010-2019.csv')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
pd.read_csv('book1.csv')
# Out:
#         Susanta Panda kumarsusant.bbl@gmail.com     Kalinga  758034  M
# 0  Madhu Chanda Panda     Madhususant@gmail.com     Kalinga  758034  F
# 1      Kamalini Panda           Kp142@gmail.com  Matkambeda  758035  F
# 2  Gagan Bihari Panda             gbp@gmail.com  Matkambeda  758035  M

# %%
pd.read_csv('book1.csv',names = ['Name','Email','Address','Pin','Gender'])
# Out:
#                  Name                      Email     Address     Pin Gender
# 0       Susanta Panda  kumarsusant.bbl@gmail.com     Kalinga  758034      M
# 1  Madhu Chanda Panda      Madhususant@gmail.com     Kalinga  758034      F
# 2      Kamalini Panda            Kp142@gmail.com  Matkambeda  758035      F
# 3  Gagan Bihari Panda              gbp@gmail.com  Matkambeda  758035      M

# %%
pd.read_csv('Book1cvs.csv',sep='.')
# Out:
#                                                                          name,email,address,pin,gender
# Susanta Panda      kumarsusant       bbl@gmail com        Kalinga 758034                         M,,,,
# Madhu Chanda Panda Madhususant@gmail com       Kalinga    758034  F,,,,                            NaN
# Kamalini Panda     Kp142@gmail       com       Matkambeda 758035  F,,,,                            NaN
# Gagan Bihari Panda gbp@gmail         com       Matkambeda 758035  M,,,,                            NaN

# %%
new = pd.read_csv('book1.csv',names = ['Name','Email','Address','Pin','Gender'])

# %%
new
# Out:
#                  Name                      Email     Address     Pin Gender
# 0       Susanta Panda  kumarsusant.bbl@gmail.com     Kalinga  758034      M
# 1  Madhu Chanda Panda      Madhususant@gmail.com     Kalinga  758034      F
# 2      Kamalini Panda            Kp142@gmail.com  Matkambeda  758035      F
# 3  Gagan Bihari Panda              gbp@gmail.com  Matkambeda  758035      M

# %%
pd.read_csv('book1.csv',names = ['Name','Email','Address','Pin','Gender'], skiprows = [1])
# Out:
#                  Name                      Email     Address     Pin Gender
# 0       Susanta Panda  kumarsusant.bbl@gmail.com     Kalinga  758034      M
# 1      Kamalini Panda            Kp142@gmail.com  Matkambeda  758035      F
# 2  Gagan Bihari Panda              gbp@gmail.com  Matkambeda  758035      M

# %%
pd.read_csv('population-2010-2019.csv',names = ['LocID','Location','Time','AgeGrp','AgeGrpStart','AgeGrpSpan','PopMale','PopFemale','PopTotal'],skiprows = [0,1])
# Out:
#        LocID             Location    Time AgeGrp  AgeGrpStart  AgeGrpSpan  \
# 0          4          Afghanistan  2010.0    0-4          0.0         5.0
# 1          8              Albania  2010.0    0-4          0.0         5.0
# 2         12              Algeria  2010.0    0-4          0.0         5.0
# 3         24               Angola  2010.0    0-4          0.0         5.0
# 4         28  Antigua and Barbuda  2010.0    0-4          0.0         5.0
# ...      ...                  ...     ...    ...          ...         ...
# 41790    430              Liberia  2019.0   100+        100.0        -1.0
# 41791    882                Samoa  2019.0   100+        100.0        -1.0
# 41792    768                 Togo  2019.0   100+        100.0        -1.0
# 41793    776                Tonga  2019.0   100+        100.0        -1.0
# 41794    548              Vanuatu  2019.0   100+        100.0        -1.0
#
#         PopMale  PopFemale  PopTotal
# 0      2715.070   2600.535  5315.605
# ...

# %%
df = pd.read_csv('population-2010-2019.csv',names = ['LocID','Location','Time','AgeGrp','AgeGrpStart','AgeGrpSpan','PopMale','PopFemale','PopTotal'],skiprows = [0,1])

# %%
df.dtypes
# Out:
# LocID            int64
# Location        object
# Time           float64
# AgeGrp          object
# AgeGrpStart    float64
# AgeGrpSpan     float64
# PopMale        float64
# PopFemale      float64
# PopTotal       float64
# dtype: object

# %%
df.head()
# Out:
#    LocID             Location    Time AgeGrp  AgeGrpStart  AgeGrpSpan  \
# 0      4          Afghanistan  2010.0    0-4          0.0         5.0
# 1      8              Albania  2010.0    0-4          0.0         5.0
# 2     12              Algeria  2010.0    0-4          0.0         5.0
# 3     24               Angola  2010.0    0-4          0.0         5.0
# 4     28  Antigua and Barbuda  2010.0    0-4          0.0         5.0
#
#     PopMale  PopFemale  PopTotal
# 0  2715.070   2600.535  5315.605
# 1    92.622     81.239   173.861
# 2  1966.415   1885.869  3852.284
# 3  2233.041   2239.035  4472.076
# 4     3.543      3.436     6.979

# %%
df.tail()
# Out:
#        LocID Location    Time AgeGrp  AgeGrpStart  AgeGrpSpan  PopMale  \
# 41790    430  Liberia  2019.0   100+        100.0        -1.0      0.0
# 41791    882    Samoa  2019.0   100+        100.0        -1.0      0.0
# 41792    768     Togo  2019.0   100+        100.0        -1.0      0.0
# 41793    776    Tonga  2019.0   100+        100.0        -1.0      0.0
# 41794    548  Vanuatu  2019.0   100+        100.0        -1.0      0.0
#
#        PopFemale  PopTotal
# 41790        0.0       0.0
# 41791        0.0       0.0
# 41792        0.0       0.0
# 41793        0.0       0.0
# 41794        0.0       0.0

# %%
df.columns
# Out:
# Index(['LocID', 'Location', 'Time', 'AgeGrp', 'AgeGrpStart', 'AgeGrpSpan',
#        'PopMale', 'PopFemale', 'PopTotal'],
#       dtype='object')

# %%
df
# Out:
#        LocID             Location    Time AgeGrp  AgeGrpStart  AgeGrpSpan  \
# 0          4          Afghanistan  2010.0    0-4          0.0         5.0
# 1          8              Albania  2010.0    0-4          0.0         5.0
# 2         12              Algeria  2010.0    0-4          0.0         5.0
# 3         24               Angola  2010.0    0-4          0.0         5.0
# 4         28  Antigua and Barbuda  2010.0    0-4          0.0         5.0
# ...      ...                  ...     ...    ...          ...         ...
# 41790    430              Liberia  2019.0   100+        100.0        -1.0
# 41791    882                Samoa  2019.0   100+        100.0        -1.0
# 41792    768                 Togo  2019.0   100+        100.0        -1.0
# 41793    776                Tonga  2019.0   100+        100.0        -1.0
# 41794    548              Vanuatu  2019.0   100+        100.0        -1.0
#
#         PopMale  PopFemale  PopTotal
# 0      2715.070   2600.535  5315.605
# ...

# %%
df['PopTotal']
# Out:
# 0        5315.605
# 1         173.861
# 2        3852.284
# 3        4472.076
# 4           6.979
#            ...
# 41790       0.000
# 41791       0.000
# 41792       0.000
# 41793       0.000
# 41794       0.000
# Name: PopTotal, Length: 41795, dtype: float64

# %%
new =df['PopTotal']

# %%
type(new)
# Out:
# pandas.core.series.Series

# %%
df[['Location','PopTotal','AgeGrp']]
# Out:
#                   Location  PopTotal AgeGrp
# 0              Afghanistan  5315.605    0-4
# 1                  Albania   173.861    0-4
# 2                  Algeria  3852.284    0-4
# 3                   Angola  4472.076    0-4
# 4      Antigua and Barbuda     6.979    0-4
# ...                    ...       ...    ...
# 41790              Liberia     0.000   100+
# 41791                Samoa     0.000   100+
# 41792                 Togo     0.000   100+
# 41793                Tonga     0.000   100+
# 41794              Vanuatu     0.000   100+
#
# [41795 rows x 3 columns]

# %%
new = df[['Location','PopTotal','AgeGrp']] ## UNDER LIST --- DATAFRAME

# %%
type(new)
# Out:
# pandas.core.frame.DataFrame

# %%
pd.read_excel('columnfromexample-210509-235702.xlsx',sheet_name = 'Split Name2')
# Out:
#     Account Number   Customer Name Account Type  Closing Balance
# 0       1100552210       SalilJain      Current            12500
# 1       1100552211     VikasSharma       Saving             7000
# 2       1100552212     VijayKapoor      Current             5200
# 3       1100552213      ArjunSingh      Current             4000
# 4       1100552214      ManojKumar      Current            15000
# ..             ...             ...          ...              ...
# 90      1100552300     MukeshSingh      Current             5000
# 91      1100552301       VedKishor       Saving             7000
# 92      1100552302  HarminderSingh      Current             5200
# 93      1100552303    ParveenKumar      Current             4000
# 94      1100552304    SudhirRathee      Current             2500
#
# [95 rows x 4 columns]

# %%
pd.read_excel('columnfromexample-210509-235702.xlsx')
# Out:
#     Account Number    Customer Name Account Type  Closing Balance
# 0       1100552210       Salil Jain      Current            12500
# 1       1100552211     Vikas Sharma       Saving             7000
# 2       1100552212     Vijay Kapoor      Current             5200
# 3       1100552213      Arjun Singh      Current             4000
# 4       1100552214      Manoj Kumar      Current            15000
# ..             ...              ...          ...              ...
# 90      1100552300     Mukesh Singh      Current             5000
# 91      1100552301       Ved Kishor       Saving             7000
# 92      1100552302  Harminder Singh      Current             5200
# 93      1100552303    Parveen Kumar      Current             4000
# 94      1100552304    Sudhir Rathee      Current             2500
#
# [95 rows x 4 columns]

# %%
excel = pd.ExcelFile('columnfromexample-210509-235702.xlsx')

# %%
excel.sheet_names
# Out:
# ['Split Name1', 'Split Name2', 'Join Name', 'Clean Data', 'Split', 'Date']

# %%
pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
pd.read_html('https://www.basketball-reference.com/leagues/NBA_2015_totals.html')
# Out:
# [      Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
#  0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
#  1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
#  2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
#  3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
#  4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
#  ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
#  670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
#  671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
#  672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
#  673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
#  674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
df = pd.read_html('https://www.basketball-reference.com/leagues/NBA_2015_totals.html')

# %%
type(df)
# Out:
# list

# %%
len(df)
# Out:
# 1

# %%
df[0]
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
type(df[0])
# Out:
# pandas.core.frame.DataFrame

# %%
df1 = df[0]

# %%
df1.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
df1[['Player','Age','Tm']]
# Out:
#              Player Age   Tm
# 0        Quincy Acy  24  NYK
# 1      Jordan Adams  20  MEM
# 2      Steven Adams  21  OKC
# 3       Jeff Adrien  28  MIN
# 4     Arron Afflalo  29  TOT
# ..              ...  ..  ...
# 670  Thaddeus Young  26  TOT
# 671  Thaddeus Young  26  MIN
# 672  Thaddeus Young  26  BRK
# 673     Cody Zeller  22  CHO
# 674    Tyler Zeller  25  BOS
#
# [675 rows x 3 columns]

# %%
df1.dtypes
# Out:
# Rk        object
# Player    object
# Pos       object
# Age       object
# Tm        object
# G         object
# GS        object
# MP        object
# FG        object
# FGA       object
# FG%       object
# 3P        object
# 3PA       object
# 3P%       object
# 2P        object
# 2PA       object
# 2P%       object
# eFG%      object
# FT        object
# FTA       object
# FT%       object
# ORB       object
# DRB       object
# TRB       object
# AST       object
# STL       object
# BLK       object
# TOV       object
# PF        object
# PTS       object
# dtype: object

# %%
df1
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
df1.to_csv('NBS.CSV',index = False)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-23-9bfb3592489d> in <module>
# ----> 1 df1.to_csv('NBS.CSV',index = False)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3385         )
#    3386
# -> 3387         return DataFrameRenderer(formatter).to_csv(
#    3388             path_or_buf,
#    3389             line_terminator=line_terminator,
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
# ...

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is F229-5898
#
#  Directory of C:\Users\pc
#
# 31-05-2022  07:24    <DIR>          .
# 31-05-2022  07:24    <DIR>          ..
# 31-05-2022  06:57    <DIR>          .ipynb_checkpoints
# 18-05-2022  12:39    <DIR>          .ipython
# 18-05-2022  18:41    <DIR>          .jupyter
# 22-03-2022  23:27    <DIR>          3D Objects
# 18-05-2022  08:47    <DIR>          anaconda3
# 30-05-2022  15:11               223 Book1.csv
# 30-05-2022  16:04               270 Book1cvs.csv
# 30-05-2022  21:41            96,093 ColumnfromExample-210509-235702.xlsx
# 22-03-2022  23:27    <DIR>          Contacts
# 30-05-2022  23:49    <DIR>          Desktop
# 26-05-2022  09:07    <DIR>          Documents
# 30-05-2022  22:07    <DIR>          Downloads
# 22-03-2022  23:27    <DIR>          Favorites
# 22-03-2022  23:27    <DIR>          Links
# 22-03-2022  23:27    <DIR>          Music
# 31-05-2022  07:24            81,552 NBS.CSV
# ...

# %%
pd.read_html('https://en.wikipedia.org/wiki/Demographics_of_India')
# Out:
# [               Demographics of India  \
#  0   India population pyramid in 2020
#  1                         Population
#  2                            Density
#  3                        Growth rate
#  4                         Birth rate
#  5                         Death rate
#  6                    Life expectancy
#  7                             • male
#  8                           • female
#  9                     Fertility rate
#  10             Infant mortality rate
#  11                     Age structure
#  12                        0–14 years
#  13                       15–64 years
#  14                       65 and over
#  15                         Sex ratio
#  16                             Total
#  17                          At birth
#  18                          Under 15
#  19                       15–64 years
#  20                       65 and over
#  21                       Nationality
#  22                      Major ethnic
# ...

# %%
df = pd.read_html('https://en.wikipedia.org/wiki/Demographics_of_India')

# %%
type(df)
# Out:
# list

# %%
len(df)
# Out:
# 38

# %%
df[0].to_csv()
# Out:
#                Demographics of India  \
# 0   India population pyramid in 2020
# 1                         Population
# 2                            Density
# 3                        Growth rate
# 4                         Birth rate
# 5                         Death rate
# 6                    Life expectancy
# 7                             • male
# 8                           • female
# 9                     Fertility rate
# 10             Infant mortality rate
# 11                     Age structure
# 12                        0–14 years
# 13                       15–64 years
# 14                       65 and over
# 15                         Sex ratio
# 16                             Total
# 17                          At birth
# 18                          Under 15
# 19                       15–64 years
# 20                       65 and over
# 21                       Nationality
# 22                      Major ethnic
# 23                          Language
# ...

# %%
df[1]
# Out:
#          Year Aggregate average                                    Period  \
#          Year        Population % of World population              Period
# 0   10,000 BC              1000                 0.83%           Stone Age
# 1     4000 BC           1000000                30.83%           Stone Age
# 2     2000 BC          13000000               37.143%          Bronze Age
# 3      500 BC          83400000                41.70%            Iron Age
# 4      400 BC         102600000                43.96%            Iron Age
# 5      200 BC         142900000                47.63%          Maurya era
# 6        1 AD         166700000                35.56%       Classical era
# 7         200         200000000                36.15%       Classical era
# 8         400         250000000                   40%       Classical era
# 9         500         285800000                43.58%       Classical era
# 10        600         333400000                48.83%  Early medieval era
# ...

# %%
Data = """
{"Name" : "Susanta Kumar Panda",
"Email ID" : "Kumarsusant.bbl@gmail.com",
"IT" : ["DATA ANALYST","BUSINESS ANALYST", "TRAINER"],
"Company" :["NF","TATA","OMC"]
}
"""

# %%
import json

# %%
type(Data)
# Out:
# str

# %%
result = json.loads(Data)

# %%
result
# Out:
# {'Name': 'Susanta Kumar Panda',
#  'Email ID': 'Kumarsusant.bbl@gmail.com',
#  'IT': ['DATA ANALYST', 'BUSINESS ANALYST', 'TRAINER'],
#  'Company': ['NF', 'TATA', 'OMC']}

# %%
type(result)
# Out:
# dict

# %%
pd.DataFrame(result).to_csv('Json data')

# %%
pd.DataFrame(result)
# Out:
#                   Name                   Email ID                IT Company
# 0  Susanta Kumar Panda  Kumarsusant.bbl@gmail.com      DATA ANALYST      NF
# 1  Susanta Kumar Panda  Kumarsusant.bbl@gmail.com  BUSINESS ANALYST    TATA
# 2  Susanta Kumar Panda  Kumarsusant.bbl@gmail.com           TRAINER     OMC

# %%
pd.DataFrame(result['IT'])
# Out:
#                   0
# 0      DATA ANALYST
# 1  BUSINESS ANALYST
# 2           TRAINER

# %%
Data["Company"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-91-d1a41480001e> in <module>
# ----> 1 Data["Company"]
#
# TypeError: string indices must be integers

# %%
# if there is mismatch in the Json data then delete /remove the data

# %%
# del data["name of the column"]

# %%
pd.read_json('Sample Json File with 500 Records.json')
# Out:
#                                                  feeds  totalFeed
# 0    {'id': 2140, 'title': 'gj', 'description': 'gh...        125
# 1    {'id': 2139, 'title': 'dfg', 'description': 'd...        125
# 2    {'id': 2138, 'title': 'TEst Video', 'descripti...        125
# 3    {'id': 2137, 'title': 'QQ', 'description': 'qq...        125
# 4    {'id': 2136, 'title': 'gj', 'description': 'gh...        125
# ..                                                 ...        ...
# 495  {'id': 53, 'title': 'new one', 'description': ...        125
# 496  {'id': 52, 'title': 'new one', 'description': ...        125
# 497  {'id': 51, 'title': 'ssfdfd', 'description': '...        125
# 498  {'id': 50, 'title': 'Test Code', 'description'...        125
# 499  {'id': 49, 'title': 'A mobile phone is a wirel...        125
#
# [500 rows x 2 columns]

# %%
jn = pd.read_json('Sample Json File with 500 Records.json')

# %%
jn["feeds"]
# Out:
# 0      {'id': 2140, 'title': 'gj', 'description': 'gh...
# 1      {'id': 2139, 'title': 'dfg', 'description': 'd...
# 2      {'id': 2138, 'title': 'TEst Video', 'descripti...
# 3      {'id': 2137, 'title': 'QQ', 'description': 'qq...
# 4      {'id': 2136, 'title': 'gj', 'description': 'gh...
#                              ...
# 495    {'id': 53, 'title': 'new one', 'description': ...
# 496    {'id': 52, 'title': 'new one', 'description': ...
# 497    {'id': 51, 'title': 'ssfdfd', 'description': '...
# 498    {'id': 50, 'title': 'Test Code', 'description'...
# 499    {'id': 49, 'title': 'A mobile phone is a wirel...
# Name: feeds, Length: 500, dtype: object

# %%
type(jn)
# Out:
# pandas.core.frame.DataFrame

# %%
url = pd.read_json('https://api.github.com/repos/pandas-dev/pandas/issues')

# %%
url
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
import requests
url = ('https://api.github.com/repos/pandas-dev/pandas/issues')

# %%
data = requests.get(url)

# %%
data
# Out:
# <Response [200]>

# %%
data1 = data.json()

# %%
data1
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47179',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47179/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47179/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47179/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/47179',
#   'id': 1253140620,
#   'node_id': 'PR_kwDOAA0YD844tFIV',
#   'number': 47179,
#   'title': 'CI: Versioneer not picking up version in 32-bit build',
#   'user': {'login': 'lithomas1',
#    'id': 47963215,
#    'node_id': 'MDQ6VXNlcjQ3OTYzMjE1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/47963215?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/lithomas1',
#    'html_url': 'https://github.com/lithomas1',
# ...

# %%
len(data1)
# Out:
# 30

# %%
data1[0]
# Out:
# {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47179',
#  'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#  'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47179/labels{/name}',
#  'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47179/comments',
#  'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47179/events',
#  'html_url': 'https://github.com/pandas-dev/pandas/pull/47179',
#  'id': 1253140620,
#  'node_id': 'PR_kwDOAA0YD844tFIV',
#  'number': 47179,
#  'title': 'CI: Versioneer not picking up version in 32-bit build',
#  'user': {'login': 'lithomas1',
#   'id': 47963215,
#   'node_id': 'MDQ6VXNlcjQ3OTYzMjE1',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/47963215?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/lithomas1',
#   'html_url': 'https://github.com/lithomas1',
#   'followers_url': 'https://api.github.com/users/lithomas1/followers',
# ...

# %%
data1[0]['user']
# Out:
# {'login': 'lithomas1',
#  'id': 47963215,
#  'node_id': 'MDQ6VXNlcjQ3OTYzMjE1',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/47963215?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/lithomas1',
#  'html_url': 'https://github.com/lithomas1',
#  'followers_url': 'https://api.github.com/users/lithomas1/followers',
#  'following_url': 'https://api.github.com/users/lithomas1/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/lithomas1/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/lithomas1/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/lithomas1/subscriptions',
#  'organizations_url': 'https://api.github.com/users/lithomas1/orgs',
#  'repos_url': 'https://api.github.com/users/lithomas1/repos',
#  'events_url': 'https://api.github.com/users/lithomas1/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/lithomas1/received_events',
#  'type': 'User',
# ...

# %%
data1[0]['user']['id']
# Out:
# 47963215

# %%
for i in range (len(data1)):
    print(data1[i]['user']['id'])
# Out:
# 47963215
# 39504233
# 45562402
# 90400333
# 36087062
# 1073189
# 38034577
# 13159005
# 22665904
# 22665904
# 81615079
# 63769209
# 14581281
# 8078968
# 45562402
# 175722
# 175722
# 15113894
# 76659116
# 61934744
# 61934744
# 7035647
# 22875722
# 8726321
# 70319929
# 1736354
# 61438033
# 6618166
# 50434302
# 8078968

# %%
pd.DataFrame(data1, columns = ['html_url','id','node_id','number','user'])
# Out:
#                                              html_url          id  \
# 0     https://github.com/pandas-dev/pandas/pull/47179  1253140620
# 1     https://github.com/pandas-dev/pandas/pull/47178  1253109932
# 2     https://github.com/pandas-dev/pandas/pull/47177  1253100088
# 3   https://github.com/pandas-dev/pandas/issues/47176  1253037449
# 4   https://github.com/pandas-dev/pandas/issues/47173  1252918972
# 5   https://github.com/pandas-dev/pandas/issues/47172  1252819153
# 6   https://github.com/pandas-dev/pandas/issues/47171  1252748214
# 7   https://github.com/pandas-dev/pandas/issues/47169  1252634463
# 8     https://github.com/pandas-dev/pandas/pull/47168  1252463876
# 9   https://github.com/pandas-dev/pandas/issues/47167  1252451093
# 10  https://github.com/pandas-dev/pandas/issues/47166  1252411370
# 11    https://github.com/pandas-dev/pandas/pull/47164  1251815907
# 12  https://github.com/pandas-dev/pandas/issues/47163  1251802372
# ...

# %%
User = pd.DataFrame(data1, columns = ['html_url','id','node_id','number'])

# %%
# User.to_csv('User_csv')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-119-c420e4bd291a> in <module>
# ----> 1 User.to_cs
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'to_cs'

# %%
User.to_csv('User_csv')

# %%
pd
# Out:
# <module 'pandas' from 'C:\\Users\\pc\\anaconda3\\lib\\site-packages\\pandas\\__init__.py'>

# %%
pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df = pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df[['Sex','Name']]
# Out:
#         Sex                                               Name
# 0      male                            Braund, Mr. Owen Harris
# 1    female  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2    female                             Heikkinen, Miss. Laina
# 3    female       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4      male                           Allen, Mr. William Henry
# ..      ...                                                ...
# 886    male                              Montvila, Rev. Juozas
# 887  female                       Graham, Miss. Margaret Edith
# 888  female           Johnston, Miss. Catherine Helen "Carrie"
# 889    male                              Behr, Mr. Karl Howell
# 890    male                                Dooley, Mr. Patrick
#
# [891 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df[['Name','Sex','Ticket','Cabin','Embarked']]
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %%
df.dtypes == 'object'
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
type(df.dtypes)
# Out:
# pandas.core.series.Series

# %%
df.dtypes[df.dtypes == 'object']
# Out:
# Name        object
# Sex         object
# Ticket      object
# Cabin       object
# Embarked    object
# dtype: object

# %%
df.dtypes[df.dtypes == 'object'].index
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
col_name = df.dtypes[df.dtypes == 'object'].index

# %%
df[col_name]
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %%
df[col_name].describe()
# Out:
#                                                      Name   Sex Ticket  \
# count                                                 891   891    891
# unique                                                891     2    681
# top     Andersson, Mrs. Anders Johan (Alfrida Konstant...  male   1601
# freq                                                    1   577      7
#
#               Cabin Embarked
# count           204      889
# unique          147        3
# top     C23 C25 C27        S
# freq              4      644

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Discount']=23  ## add new column

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
## give me first 15 records

# %%
df[0:15]
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %%
df['Name'][0:15]
# Out:
# 0                               Braund, Mr. Owen Harris
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                Heikkinen, Miss. Laina
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                              Allen, Mr. William Henry
# 5                                      Moran, Mr. James
# 6                               McCarthy, Mr. Timothy J
# 7                        Palsson, Master. Gosta Leonard
# 8     Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                   Nasser, Mrs. Nicholas (Adele Achem)
# 10                      Sandstrom, Miss. Marguerite Rut
# 11                             Bonnell, Miss. Elizabeth
# 12                       Saundercock, Mr. William Henry
# 13                          Andersson, Mr. Anders Johan
# 14                 Vestrom, Miss. Hulda Amanda Adolfina
# Name: Name, dtype: object

# %%
df['Name'][0:15:2]
# Out:
# 0                               Braund, Mr. Owen Harris
# 2                                Heikkinen, Miss. Laina
# 4                              Allen, Mr. William Henry
# 6                               McCarthy, Mr. Timothy J
# 8     Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 10                      Sandstrom, Miss. Marguerite Rut
# 12                       Saundercock, Mr. William Henry
# 14                 Vestrom, Miss. Hulda Amanda Adolfina
# Name: Name, dtype: object

# %%
df['Name'][:-1]
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 885                 Rice, Mrs. William (Margaret Norton)
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# Name: Name, Length: 890, dtype: object

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# find the null values

# %%
df['Age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
df['Age'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888     True
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool

# %%
df['Age'].isnull() == True
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888     True
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool

# %%
df[df['Age'].isnull() == True].index
# Out:
# Int64Index([  5,  17,  19,  26,  28,  29,  31,  32,  36,  42,
#             ...
#             832, 837, 839, 846, 849, 859, 863, 868, 878, 888],
#            dtype='int64', length=177)

# %%
len(df[df['Age'].isnull() == True].index)   # total blank
# Out:
# 177

# %%
# show me the blank recordes

# %%
ind = df[df['Age'].isnull() == True].index

# %%
df.loc[ind]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
# find the person who paid high price

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Fare']
# Out:
# 0       7.2500
# 1      71.2833
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 886    13.0000
# 887    30.0000
# 888    23.4500
# 889    30.0000
# 890     7.7500
# Name: Fare, Length: 891, dtype: float64

# %%
max(df['Fare'])
# Out:
# 512.3292

# %%
df['Fare'] == max(df['Fare'])
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Fare, Length: 891, dtype: bool

# %%
df[df['Fare'] == max(df['Fare'])]
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked  \
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C
#
#      Discount
# 258        23
# 679        23
# 737        23

# %%
df[df['Fare'] == max(df['Fare'])]['Name']
# Out:
# 258                      Ward, Miss. Anna
# 679    Cardeza, Mr. Thomas Drake Martinez
# 737                Lesurer, Mr. Gustave J
# Name: Name, dtype: object
